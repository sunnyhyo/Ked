# %%
import pandas as pd

# %%
korea00 = pd.read_csv('./2000korea3.csv', sep = ',')
korea01 = pd.read_csv('./2001korea2.csv', sep = ',')
korea02 = pd.read_csv('./2002korea2.csv', sep = ',')
korea03 = pd.read_csv('./2003korea2.csv', sep = ',')
korea04 = pd.read_csv('./2004korea2.csv', sep = ',')
korea05 = pd.read_csv('./2005korea.csv', sep = ',')
korea05_1 = pd.read_csv('./2005korea1.csv', sep = ',')
korea05_2 = pd.read_excel('./2005korea2.xlsx', sep = ',')
korea06 = pd.read_csv('./2006korea1.csv', sep = ',')
korea07 = pd.read_csv('./2007korea3.csv', sep = ',')
korea08 = pd.read_csv('./2008korea2.csv', sep = ',')
korea09 = pd.read_csv('./2009korea2.csv', sep = ',')
korea10 = pd.read_csv('./2010korea2.csv', sep = ',')
korea11 = pd.read_csv('./2011korea2.csv', sep = ',')
# Out:
# C:\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
korea00.groupby(['year','month']).size()
# Out:
# year  month
# 2000  1        4870
#       2        4950
#       3        5052
#       4        5001
#       5        5021
#       6        5036
#       7        5046
#       8        5051
#       9        5059
#       10       5064
#       11       5067
#       12       5071
# 2007  1        6300
#       2        6116
#       3        5814
#       4        6084
#       5        6072
#       6        6144
#       7        6210
#       8        6252
#       9        6276
#       10       5806
#       11       5736
#       12       5760
# dtype: int64

# %%
korea01.groupby(['year','month']).size()
# Out:
# year  month
# 2001  1        1099
#       2        1099
#       3        1099
#       4        1099
#       5        1099
#       6        1099
#       7        1099
#       8        1099
#       9        1099
#       10       1099
#       11       1099
#       12       1099
# 2002  1        5240
#       2        3130
#       3         729
#       4          29
#       5        2239
#       6         739
#       7         669
#       8         589
#       9         919
#       10       1099
#       11       1099
#       12       1099
# dtype: int64

# %%
korea02.groupby(['year','month']).size()
# Out:
# year  month
# 2002  1        5240
#       2        3130
#       3         729
#       4          29
#       5        2239
#       6         739
#       7         669
#       8         589
#       9         919
#       10       1099
#       11       1099
#       12       1099
# dtype: int64

# %%
korea03.groupby(['year','month']).size()
# Out:
# year  month
# 2003  1        5980
#       2        5684
#       3        5264
#       4        5748
#       5        5868
#       6        5934
#       7        6060
#       8        6120
#       9        6138
#       10       6156
#       11       6192
#       12       6210
# 2004  1        5049
#       2        5900
#       3        6212
#       4        6492
#       5        5322
#       6        5684
#       7        5740
#       8        5804
#       9        5844
#       10       5876
#       11       5892
#       12       5916
# dtype: int64

# %%
korea04.groupby(['year','month']).size()
# Out:
# year  month
# 2004  1        5049
#       2        5900
#       3        6212
#       4        6492
#       5        5322
#       6        5684
#       7        5740
#       8        5804
#       9        5844
#       10       5876
#       11       5892
#       12       5916
# dtype: int64

# %%
korea05.groupby(['year','month']).size()
# Out:
# year  month
# 2005  9        6228
#       10        100
#       11       4280
#       12         29
# 2006  1         100
#       2        3099
#       3         800
# dtype: int64

# %%
korea05_1.groupby(['year','month']).size()
# Out:
# year  month
# 2005  1          29
#       2         750
#       3          29
#       4          29
#       5          29
#       6         779
# 2006  1        3130
#       2        1169
#       4        1229
#       5          29
#       6         879
#       7        1409
#       8          89
#       9        1979
#       10         29
#       11       1179
#       12        929
# dtype: int64

# %%
korea05_2.groupby(['year','month']).size()
# Out:
# year  month
# 2005  1          29
#       2         750
#       3          29
#       4          29
#       5          29
#       6         779
# 2006  1        3130
#       2        1169
#       4        1229
#       5          29
#       6         879
#       7        1409
#       8          89
#       9        1979
#       10         29
#       11       1179
#       12        929
# dtype: int64

# %%
korea06.groupby(['year','month']).size()
# Out:
# year  month
# 2006  1        3130
#       2        1169
#       4        1229
#       5          29
#       6         879
#       7        1409
#       8          89
#       9        1979
#       10         29
#       11       1179
#       12        929
# dtype: int64

# %%
korea07.groupby(['year','month']).size()
# Out:
# year  month
# 2007  1        6300
#       2        6116
#       3        5814
#       4        6084
#       5        6072
#       6        6144
#       7        6210
#       8        6252
#       9        6276
#       10       5806
#       11       5736
#       12       5760
# dtype: int64

# %%
korea08.groupby(['year','month']).size()
# Out:
# year  month
# 2008  1        6300
#       2        6140
#       3        5808
#       4        6036
#       5        6132
#       6        6210
#       7        6264
#       8        5708
#       9        5728
#       10       5744
#       11       5764
#       12       5784
# 2009  1          59
#       2          29
#       3        4819
#       4        5072
#       5        5089
#       6        5099
#       7        5748
#       8        5780
#       9        5812
#       10       5876
#       11       5908
#       12       5924
# 2010  1        4852
#       2        4912
#       3        4970
#       4        5012
#       5        5042
#       6        5066
#       7        5076
#       8        5084
#       9        5094
#       10       5003
#       11       5007
#       12       4088
# 2011  1        4856
#       2        4920
#       3        4976
#       4        5000
#       5        5034
#       6        5056
#       7        5066
#       8        5076
# ...

# %%
korea08.loc[korea08['year']==2008].loc[korea08['month']==5].groupby(['year','month']).page.value_counts()
# Out:
# year  month  page
# 2008  5      1       816
#              53      300
#              54      216
#              51      200
#              2       100
#              3       100
#              4       100
#              5       100
#              6       100
#              7       100
#              8       100
#              9       100
#              10      100
#              12      100
#              13      100
#              14      100
#              15      100
#              16      100
#              17      100
#              18      100
#              19      100
#              20      100
#              22      100
#              23      100
#              24      100
#              25      100
#              26      100
#              27      100
#              28      100
#              29      100
#              30      100
#              32      100
#              33      100
#              34      100
#              35      100
#              36      100
# ...

# %%
korea10.groupby(['year','month']).size()
# Out:
# year  month
# 2010  1        4852
#       2        4912
#       3        4970
#       4        5012
#       5        5042
#       6        5066
#       7        5076
#       8        5084
#       9        5094
#       10       5003
#       11       5007
#       12       4088
# 2011  1        4856
#       2        4920
#       3        4976
#       4        5000
#       5        5034
#       6        5056
#       7        5066
#       8        5076
#       9        5086
#       10       5090
#       11       5098
#       12       5001
# dtype: int64

# %%
korea11.groupby(['year','month']).size()
# Out:
# year  month
# 2011  1        4856
#       2        4920
#       3        4976
#       4        5000
#       5        5034
#       6        5056
#       7        5066
#       8        5076
#       9        5086
#       10       5090
#       11       5098
#       12       5001
# dtype: int64

# %%
korea00
# Out:
#         year  month country  \
# 0       2007      1      한국
# 1       2007      1      한국
# 2       2007      1      한국
# 3       2007      1      한국
# 4       2007      1      한국
# 5       2007      1      한국
# 6       2007      1      한국
# 7       2007      1      한국
# 8       2007      1      한국
# 9       2007      1      한국
# 10      2007      1      한국
# 11      2007      1      한국
# 12      2007      1      한국
# 13      2007      1      한국
# 14      2007      1      한국
# 15      2007      1      한국
# 16      2007      1      한국
# 17      2007      1      한국
# 18      2007      1      한국
# 19      2007      1      한국
# 20      2007      1      한국
# 21      2007      1      한국
# 22      2007      1      한국
# 23      2007      1      한국
# 24      2007      1      한국
# 25      2007      1      한국
# 26      2007      1      한국
# 27      2007      1      한국
# 28      2007      1      한국
# 29      2007      1      한국
# ...      ...    ...     ...
# 132828  2000     12      한국
# ...

# %% [markdown]
# # 년도별로 정리

# %%
# 2000년

korea2000 = korea00.loc[korea00['year'] == 2000].reset_index(drop=True)
korea2001 = korea01.loc[korea01['year'] == 2001].reset_index(drop=True)
# korea2002 = korea02.loc[korea02['year'] == 2002].reset_index(drop=True)
# 2002년 이상함

korea2003 = korea03.loc[korea03['year'] == 2003].reset_index(drop=True)
korea2004 = korea04.loc[korea04['year'] == 2004].reset_index(drop=True)
# korea2005 = korea05.loc[korea05['year'] == 2005].reset_index(drop=True)
# 2005년 이상함

# korea2006 = korea06.loc[korea06['year'] == 2006].reset_index(drop=True)
# 2006년 이상함

korea2007 = korea07.loc[korea07['year'] == 2007].reset_index(drop=True)
korea2008 = korea08.loc[korea08['year'] == 2008].reset_index(drop=True)
# korea2009 = korea08.loc[korea08['year'] == 2009].reset_index(drop=True)
# 2009년 1, 2월 이상함

korea2010 = korea08.loc[korea08['year'] == 2010].reset_index(drop=True)
korea2011 = korea08.loc[korea08['year'] == 2011].reset_index(drop=True)

# %%
korea2000.to_csv('C:/Users/HS/Desktop/korea/korea2000.csv', index = False)
korea2001.to_csv('C:/Users/HS/Desktop/korea/korea2001.csv', index = False)
#korea2002.to_csv('C:/Users/HS/Desktop/korea/korea2002.csv', index = False)
korea2003.to_csv('C:/Users/HS/Desktop/korea/korea2003.csv', index = False)
korea2004.to_csv('C:/Users/HS/Desktop/korea/korea2004.csv', index = False)
#korea2005.to_csv('C:/Users/HS/Desktop/korea/korea2005.csv', index = False)
#korea2006.to_csv('C:/Users/HS/Desktop/korea/korea2006.csv', index = False)
korea2007.to_csv('C:/Users/HS/Desktop/korea/korea2007.csv', index = False)
korea2008.to_csv('C:/Users/HS/Desktop/korea/korea2008.csv', index = False)
#korea2009.to_csv('C:/Users/HS/Desktop/korea/korea2009.csv', index = False)
korea2010.to_csv('C:/Users/HS/Desktop/korea/korea2010.csv', index = False)
korea2011.to_csv('C:/Users/HS/Desktop/korea/korea2011.csv', index = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-172b53172111> in <module>()
# ----> 1 korea2000.to_csv('C:/Users/HS/Desktop/korea/korea2000.csv', index = False)
#       2 korea2001.to_csv('C:/Users/HS/Desktop/korea/korea2001.csv', index = False)
#       3 #korea2002.to_csv('C:/Users/HS/Desktop/korea/korea2002.csv', index = False)
#       4 korea2003.to_csv('C:/Users/HS/Desktop/korea/korea2003.csv', index = False)
#       5 korea2004.to_csv('C:/Users/HS/Desktop/korea/korea2004.csv', index = False)
#
# NameError: name 'korea2000' is not defined

# %%
import pandas as pd

# %%
korea2000 = pd.read_csv('C:/Users/HS/Desktop/korea/korea2000.csv', sep = ',')
korea2000.loc[korea2000['month']==1].groupby(['year', 'month', 'page']).size()
# Out:
# year  month  page
# 2000  1      1       535
#              2       100
#              3       100
#              4       100
#              5       100
#              6       100
#              7       100
#              8       100
#              9       100
#              10      100
#              12      100
#              13      100
#              14      100
#              15      100
#              16      100
#              17      100
#              18      100
#              19      100
#              20      100
#              22      100
#              23      100
#              24      100
#              25      100
#              26      100
#              27      100
#              28      100
#              29      100
#              30      100
#              32      100
#              33      100
#              34      100
#              35      100
#              36      100
#              37      100
#              38      100
#              39      100
# ...

# %%
korea2000.head()
# Out:
#    year  month country                                           SC  S_code  \
# 0  2000      1      한국         기타(바이폴라와 모스테크놀로지의 결합으로 생성된 회로를 포함한다)  854219
# 1  2000      1      한국                        제8471호에해당하는기계의부분품과부속품  847330
# 2  2000      1      한국  석유 .역청유 (원유제외 ),이들의  조제품 (석유 .역청유 70%이상포함 )  271000
# 3  2000      1      한국                              수신기기를  갖춘  송신기기  852520
# 4  2000      1      한국           실린더용량이 1,500시시를 초과하고 3,000시시 이하인 것  870323
#
#       export     import  page
# 0  1,426,633  1,088,293     1
# 1    803,790    318,609     1
# 2    649,488    466,767     1
# 3    462,020     12,049     1
# 4    411,816      4,915     1

# %%
korea2000.iloc[4823:4880,:]
# Out:
#       year  month country                                            SC  \
# 4823  2000      1      한국                        담배의  조제  또는  제조기의  부분품
# 4824  2000      1      한국                동물성 .식물성  유지의  추출  및  조제용  기계류
# 4825  2000      1      한국    파티클보오드 .건축용  섬유판의  제조용  프레스 ,목재 .콜크처리용  기계
# 4826  2000      1      한국                                         회전변환기
# 4827  2000      1      한국             양모 .섬수모제의  남자용  슈트 (편직 .크로세의  것 )
# 4828  2000      1      한국      용량 20W이하의  권선  가변저항기 (가감저항기와  전위차계  포함 )
# 4829  2000      1      한국    기타  합금강제의  기타  관과  중공프로파일 (용접한  것 ,원형횡단면 )
# 4830  2000      1      한국                                 비가단주철제의  주물제품
# 4831  2000      1      한국                                        동의  매트
# 4832  2000      1      한국                            와이어바 (정제한  동의  것 )
# 4833  2000      1      한국                             빌레트 (정제한  동의  것 )
# 4834  2000      1      한국      동 -니켈의  합금 (백동 )또는  동 -니켈 -아연의  합금 (양백 )
# ...

# %%
korea2009 = korea06.loc[korea06['year'] == 2009].reset_index(drop=True)
korea2009.to_csv('C:/Users/HS/Desktop/korea/korea2009.csv', index = False)

# %%
korea2000.loc['']
