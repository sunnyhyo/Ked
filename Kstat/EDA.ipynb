# %%
import pandas as pd
kstat= pd.read_csv('./HScode6.csv')

# %%
kstat = kstat.rename(columns= { '한국품목명_2012':'품목명'})
kstat
# Out:
#        HS_CODE_6                품목명    년도  국가        수출금액  수출증감률        수입금액  \
# 0         730719    주철제의  기타  관연결구류  2012  한국     37905.0  129.1     55112.0
# 1         730719    주철제의  기타  관연결구류  2012  중국    559171.0    6.6     38579.0
# 2         730719    주철제의  기타  관연결구류  2012  일본   2895796.0   -6.7   4556671.0
# 3         730719    주철제의  기타  관연결구류  2013  한국     24743.0  -34.7     57233.0
# 4         730719    주철제의  기타  관연결구류  2013  중국    554242.0   -0.9     45296.0
# 5         730719    주철제의  기타  관연결구류  2013  일본   3357691.0   16.0   4490318.0
# 6         730719    주철제의  기타  관연결구류  2014  한국     21355.0  -13.7     65994.0
# 7         730719    주철제의  기타  관연결구류  2014  중국    626708.0   13.1     41858.0
# 8         730719    주철제의  기타  관연결구류  2014  일본    626708.0   13.1     41858.0
# 9         730719    주철제의  기타  관연결구류  2015  한국     24525.0   14.8     59288.0
# 10        730719    주철제의  기타  관연결구류  2015  중국    594569.0   -5.1     35629.0
# ...
