# %%
# -*- coding: utf-8 -*-
"""
Created on Tue Mar  5 15:32:28 2019

@author: hyunseok
"""

# module importing
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import time

# 2. driver경로설정 및 url주소 설정
driverpath = 'C:/Users/HS/Desktop/driver/chromedriver.exe'
dr = webdriver.Chrome(driverpath)

####

# 로그인
dr.get('https://www.kita.net/login/login.do?geturl=http://stat.kita.net/stat/pmsd/china/ChinaWholeList.screen')
dr.find_element_by_id('p_member_id').send_keys('kedkorea12')
dr.find_element_by_id('p_passwd').send_keys('ked2363!')
dr.find_element_by_xpath('''//*[@id="myform"]/fieldset/button''').click()

####

df_tot = pd.DataFrame(
    columns=['year', 'month', 'country', 'SC', 'S_code', 'export', 'export_rate', 'import', 'import_rate',
             'CA'])

# 한국 URL
naraURL = ['http://stat.kita.net/stat/kts/pum/ItemImpExpList.screen']
nara = ['한국']
for site, 나라 in zip(naraURL, nara):
    # 사이트 진입
    dr.get(site)
    # 누계 -> 당월
    dr.find_element_by_xpath('''//*[@id="contents"]/div[3]/form/fieldset/div[2]/div[4]/select/option[1]''').click()
    # 100개씩 보기
    dr.find_element_by_xpath('''//*[@id="listCount"]/option[3]''').click()

    # 연도 43개
    for year_ in range(1, 44):
        dr.find_element_by_xpath(
            '''//*[@id="contents"]/div[3]/form/fieldset/div[2]/div[1]/select/option[{0}]'''.format(year_)).click()
        년 = int(dr.find_element_by_xpath(
            '''//*[@id="contents"]/div[3]/form/fieldset/div[2]/div[1]/select/option[{0}]'''.format(year_)).text)

        # 월 12개
        for month_ in range(1, 13):
            dr.find_element_by_xpath(
                '''//*[@id="contents"]/div[3]/form/fieldset/div[2]/div[2]/select/option[{0}]'''.format(month_)).click()
            월 = int(dr.find_element_by_xpath(
                '''//*[@id="contents"]/div[3]/form/fieldset/div[2]/div[2]/select/option[{0}]'''.format(month_)).text)

            # 조회
            dr.find_element_by_xpath('''//*[@id="contents"]/div[3]/form/fieldset/div[3]/a''').click()
            time.sleep(0.5)
            drt = dr.page_source
            soup = BeautifulSoup(drt, 'html.parser')

            # 데이터 적재
            코드_소 = []
            소분류 = []
            수출액 = []
            수출증감률 = []
            수입액 = []
            수입증감률 = []
            수지 = []

            # 첫페이지
            # 데이터 적재
            i = 1
            for cycle in range(int((len(soup.findAll('td', {'align': 'Left'})) - 1) / 2)):
                코드_소.append(soup.findAll('td', {'align': 'Center'})[-i + 1].text)
                소분류.append(soup.findAll('td', {'align': 'Left'})[i * 2].text)
                수출액.append(soup.findAll('td', {'align': 'Right'})[i * 10 + 5].text)
                수출증감률.append(soup.findAll('td', {'align': 'Right'})[i * 10 + 6].text)
                수입액.append(soup.findAll('td', {'align': 'Right'})[i * 10 + 7].text)
                수입증감률.append(soup.findAll('td', {'align': 'Right'})[i * 10 + 8].text)
                수지.append(soup.findAll('td', {'align': 'Right'})[i * 10 + 9].text)
                i += 1

                # 페이지 넘기기 (2페이지부터 10페이지 1~9)
                # for page_ in range(1, 10) :
                #    dr.find_element_by_xpath('''//*[@id="pageArea"]/span/a[{0}]'''.format(page_)).click()

                # 페이지 넘기기
                tmp = 1
                while 1:
                    try:
                        dr.find_element_by_xpath('''//*[@id="pageArea"]/span/a[{0}]'''.format(tmp)).click()
                        tmp += 1
                    except:
                        break;

                    # 데이터 적재
                    j = 1
                    for cycle in range(int((len(soup.findAll('td', {'align': 'Left'})) - 1) / 2)):
                        코드_소.append(soup.findAll('td', {'align': 'Center'})[-i + 1].text)
                        소분류.append(soup.findAll('td', {'align': 'Left'})[i * 2].text)
                        수출액.append(soup.findAll('td', {'align': 'Right'})[i * 10 + 5].text)
                        수출증감률.append(soup.findAll('td', {'align': 'Right'})[i * 10 + 6].text)
                        수입액.append(soup.findAll('td', {'align': 'Right'})[i * 10 + 7].text)
                        수입증감률.append(soup.findAll('td', {'align': 'Right'})[i * 10 + 8].text)
                        수지.append(soup.findAll('td', {'align': 'Right'})[i * 10 + 9].text)
                        j += 1


                # 화살표 넘기기
                dr.find_element_by_xpath('''//*[@id="pageArea"]/a[2]''').click()


df = pd.DataFrame({'year': 년, 'month': 월, 'country': 나라, 'LC': 대분류, 'MC': 중분류, 'SC': 소분류, 'S_code': 코드_소, 'export': 수출액,
                   'export_rate': 수출증감률, 'import': 수입액, 'import_rate': 수입증감률, 'CA': 수지})
df_tot = pd.concat([df_tot, df])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-4ed6cf66a372> in <module>()
#     101                         코드_소.append(soup.findAll('td', {'align': 'Center'})[-i + 1].text)
#     102                         소분류.append(soup.findAll('td', {'align': 'Left'})[i * 2].text)
# --> 103                         수출액.append(soup.findAll('td', {'align': 'Right'})[i * 10 + 5].text)
#     104                         수출증감률.append(soup.findAll('td', {'align': 'Right'})[i * 10 + 6].text)
#     105                         수입액.append(soup.findAll('td', {'align': 'Right'})[i * 10 + 7].text)
#
# C:\Anaconda3\lib\site-packages\bs4\element.py in find_all(self, name, attrs, recursive, text, limit, **kwargs)
#    1311         if not recursive:
#    1312             generator = self.children
# -> 1313         return self._find_all(name, attrs, text, limit, generator, **kwargs)
#    1314     findAll = find_all       # BS3
#    1315     findChildren = find_all  # BS2
#
# C:\Anaconda3\lib\site-packages\bs4\element.py in _find_all(self, name, attrs, text, limit, generator, **kwargs)
#     554                 break
#     555             if i:
# --> 556                 found = strainer.search(i)
#     557                 if found:
#     558                     results.append(found)
#
# C:\Anaconda3\lib\site-packages\bs4\element.py in search(self, markup)
#    1702         elif isinstance(markup, Tag):
#    1703             if not self.text or self.name or self.attrs:
# -> 1704                 found = self.search_tag(markup)
#    1705         # If it's text, make sure the text matches.
#    1706         elif isinstance(markup, NavigableString) or \
#
# C:\Anaconda3\lib\site-packages\bs4\element.py in search_tag(self, markup_name, markup_attrs)
#    1646             return "%s|%s" % (self.name, self.attrs)
#    1647
# -> 1648     def search_tag(self, markup_name=None, markup_attrs={}):
#    1649         found = None
#    1650         markup = None
#
# KeyboardInterrupt:

# %%
# -*- coding: utf-8 -*-
"""
Created on Tue Mar  5 15:32:28 2019

@author: hyunseok
"""

# module importing
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import time

# 2. driver경로설정 및 url주소 설정
driverpath = 'C:/Users/HS/Desktop/driver/chromedriver.exe'
dr = webdriver.Chrome(driverpath)

####

# 로그인
dr.get('https://www.kita.net/login/login.do?geturl=http://stat.kita.net/stat/pmsd/china/ChinaWholeList.screen')
dr.find_element_by_id('p_member_id').send_keys('kedkorea12')
dr.find_element_by_id('p_passwd').send_keys('ked2363!')
dr.find_element_by_xpath('''//*[@id="myform"]/fieldset/button''').click()

####

df_tot = pd.DataFrame(
    columns=['year', 'month', 'country', 'SC', 'S_code', 'export', 'export_rate', 'import', 'import_rate',
             'CA'])

# 한국 URL
naraURL = ['http://stat.kita.net/stat/kts/pum/ItemImpExpList.screen']
nara = ['한국']
for site, 나라 in zip(naraURL, nara):
    # 사이트 진입
    dr.get(site)
    # 누계 -> 당월
    dr.find_element_by_xpath('''//*[@id="contents"]/div[3]/form/fieldset/div[2]/div[4]/select/option[1]''').click()
    # 100개씩 보기
    dr.find_element_by_xpath('''//*[@id="listCount"]/option[3]''').click()

    # 연도 43개
    for year_ in range(1, 44):
        dr.find_element_by_xpath(
            '''//*[@id="contents"]/div[3]/form/fieldset/div[2]/div[1]/select/option[{0}]'''.format(year_)).click()
        년 = int(dr.find_element_by_xpath(
            '''//*[@id="contents"]/div[3]/form/fieldset/div[2]/div[1]/select/option[{0}]'''.format(year_)).text)

        # 월 12개
        for month_ in range(1, 13):
            dr.find_element_by_xpath(
                '''//*[@id="contents"]/div[3]/form/fieldset/div[2]/div[2]/select/option[{0}]'''.format(month_)).click()
            월 = int(dr.find_element_by_xpath(
                '''//*[@id="contents"]/div[3]/form/fieldset/div[2]/div[2]/select/option[{0}]'''.format(month_)).text)

            # 조회
            dr.find_element_by_xpath('''//*[@id="contents"]/div[3]/form/fieldset/div[3]/a''').click()
            time.sleep(0.5)
            drt = dr.page_source
            soup = BeautifulSoup(drt, 'html.parser')
            
            for page_ in range(1, 10):
                try:
                    dr.find_element_by_xpath('''//*[@id="pageArea"]/span/a[{0}]'''.format(tmp)).click()
                except:
                    break;
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-6-672e6888e451> in <module>()
#      51         for month_ in range(1, 13):
#      52             dr.find_element_by_xpath(
# ---> 53                 '''//*[@id="contents"]/div[3]/form/fieldset/div[2]/div[2]/select/option[{0}]'''.format(month_)).click()
#      54             월 = int(dr.find_element_by_xpath(
#      55                 '''//*[@id="contents"]/div[3]/form/fieldset/div[2]/div[2]/select/option[{0}]'''.format(month_)).text)
#
# C:\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     391             element = driver.find_element_by_xpath('//div/td[1]')
#     392         """
# --> 393         return self.find_element(by=By.XPATH, value=xpath)
#     394
#     395     def find_elements_by_xpath(self, xpath):
#
# C:\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     964         return self.execute(Command.FIND_ELEMENT, {
#     965             'using': by,
# --> 966             'value': value})['value']
#     967
#     968     def find_elements(self, by=By.ID, value=None):
#
# C:\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     318         response = self.command_executor.execute(driver_command, params)
#     319         if response:
# --> 320             self.error_handler.check_response(response)
#     321             response['value'] = self._unwrap_value(
#     322                 response.get('value', None))
#
# C:\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="contents"]/div[3]/form/fieldset/div[2]/div[2]/select/option[2]"}
#   (Session info: chrome=72.0.3626.121)
#   (Driver info: chromedriver=2.45.615291 (ec3682e3c9061c10f26ea9e5cdcf3c53f3f74387),platform=Windows NT 10.0.17134 x86_64)
